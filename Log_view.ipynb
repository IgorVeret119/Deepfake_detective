# %% [markdown]
# <a href="https://colab.research.google.com/github/IgorVeret119/Deepfake_detective/blob/main/Log_view.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install yadisk

# %%
import yadisk
import os
import shutil
from tqdm import tqdm

TOKEN = "y0__wgBEOqqzbcEGIesRyC5wf_SGDDNzNLrB1UKpR0S6zv56ylh9XeIO-G_bAgG"
y = yadisk.YaDisk(token=TOKEN)

remote_logs = "/IoU/logs"
local_logs = "/content/IoUScore"

# Очищаем локальную папку
if os.path.exists(local_logs):
    shutil.rmtree(local_logs)
os.makedirs(local_logs, exist_ok=True)

# Скачиваем логи
print(f"Загрузка логов с {remote_logs}")
items = list(y.listdir(remote_logs))
for item in tqdm(items):
    if item.type == "file":
        y.download(f"{remote_logs}/{item.name}", f"{local_logs}/{item.name}")

print(f"Загружено {len(items)} файлов")

# Запуск TensorBoard
# %load_ext tensorboard
# %tensorboard --logdir=/content/IoUScore
